# %%
# 각 요일별로 어떤 시간이 가장 혼잡한지를 분석 해보기
# 시간 단위로 cnt -> 혼잡했던 시간 top 3 
# 도서관 운영 시간 6시 - 23시

import pandas as pd
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
from datetime import datetime

# 한글 깨짐
font_path = 'C:\WINDOWS\FONTS\MALGUN.ttf'
font = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family = font)

# %%
# 출입일시 csv 파일 불러오기
lib_entry_exit = pd.read_csv("./데이터_도서관출입.csv", encoding = "cp949")

# 출입일시와 출/입 정보를 인덱싱한 새로운 데이터 프레임 생성
entry_or_exit_and_time = lib_entry_exit.loc[:,['출입일시','출입구']]
# print(entry_or_exit_and_time)

# 각 요일에 해당하는 출입일시와 출입만 추출
lib_mon = []
lib_tue = []
lib_wed = []
lib_thu = []
lib_fri = []
lib_sat = []
lib_sun = []

for i in entry_or_exit_and_time.index:
    datetime_d = datetime.strptime(entry_or_exit_and_time["출입일시"][i], '%Y/%m/%d %H:%M:%S')
    if datetime_d.weekday() == 0:
        lib_mon.append([entry_or_exit_and_time["출입일시"][i],entry_or_exit_and_time["출입구"][i]])
    elif datetime_d.weekday() == 1:
        lib_tue.append([entry_or_exit_and_time["출입일시"][i],entry_or_exit_and_time["출입구"][i]])
    elif datetime_d.weekday() == 2:
        lib_wed.append([entry_or_exit_and_time["출입일시"][i],entry_or_exit_and_time["출입구"][i]])
    elif datetime_d.weekday() == 3:
        lib_thu.append([entry_or_exit_and_time["출입일시"][i],entry_or_exit_and_time["출입구"][i]])
    elif datetime_d.weekday() == 4:
        lib_fri.append([entry_or_exit_and_time["출입일시"][i],entry_or_exit_and_time["출입구"][i]])
    elif datetime_d.weekday() == 5:
        lib_sat.append([entry_or_exit_and_time["출입일시"][i],entry_or_exit_and_time["출입구"][i]])
    elif datetime_d.weekday() == 6:
        lib_sun.append([entry_or_exit_and_time["출입일시"][i],entry_or_exit_and_time["출입구"][i]])    

print(lib_mon)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# 월요일에는 어떤 시간이 가장 혼잡한가 ?

# 도서관 시간 6시 ~ 23시
# lib_AtoB : A시 00분부터 A시 59분까지의 기록
lib_6to7 = []
lib_7to8 = []
lib_8to9 = []
lib_9to10 = []
lib_10to11 = []

lib_11to12 = []
lib_12to13 = []
lib_13to14 = []
lib_14to15 = []
lib_15to16 = []

lib_16to17 = []
lib_17to18 = []
lib_18to19 = []
lib_19to20 = []
lib_20to21 = []

lib_21to22 = []
lib_22to23 = []

lib_AtoB = [
    lib_6to7,
    lib_7to8,
    lib_8to9,
    lib_9to10,
    lib_10to11,
    lib_11to12,
    lib_12to13,
    lib_13to14,
    lib_14to15,
    lib_15to16,
    lib_16to17,
    lib_17to18,
    lib_18to19,
    lib_19to20,
    lib_20to21,
    lib_21to22,
    lib_22to23
]

# 시간별로 도서관 출입 (입구 - 출구)을 저장할 리스트
lib_time_cnt = []

for i in lib_mon:
    datetime_d = datetime.strptime(i[0], '%Y/%m/%d %H:%M:%S')
    if datetime_d.hour == 6:
        lib_6to7.append([i[0],i[1]])
    elif datetime_d.hour == 7:
        lib_7to8.append([i[0],i[1]])
    elif datetime_d.hour == 8:
        lib_8to9.append([i[0],i[1]])
    elif datetime_d.hour == 9:
        lib_9to10.append([i[0],i[1]])
    elif datetime_d.hour == 10:
        lib_10to11.append([i[0],i[1]])
    elif datetime_d.hour == 11:
        lib_11to12.append([i[0],i[1]])
    elif datetime_d.hour == 12:
        lib_12to13.append([i[0],i[1]])
    elif datetime_d.hour == 13:
        lib_13to14.append([i[0],i[1]])
    elif datetime_d.hour == 14:
        lib_14to15.append([i[0],i[1]])
    elif datetime_d.hour == 15:
        lib_15to16.append([i[0],i[1]])
    elif datetime_d.hour == 16:
        lib_16to17.append([i[0],i[1]])
    elif datetime_d.hour == 17:
        lib_17to18.append([i[0],i[1]])
    elif datetime_d.hour == 18:
        lib_18to19.append([i[0],i[1]])
    elif datetime_d.hour == 19:
        lib_19to20.append([i[0],i[1]])
    elif datetime_d.hour == 20:
        lib_20to21.append([i[0],i[1]])
    elif datetime_d.hour == 21:
        lib_21to22.append([i[0],i[1]])
    elif datetime_d.hour == 22:
        lib_22to23.append([i[0],i[1]])
        

for i in lib_AtoB:
    lib_cnt = 0
    for j in i:
        if (j[1] == '입구'):
            lib_cnt += 1
        elif (j[1] == '출구'):
            lib_cnt -= 1
    lib_time_cnt.append(lib_cnt)


# print(lib_time_cnt)

# 그래프 시각화    
time_list = ['6시', '7시', '8시' , '9시' , '10시' , '11시' , '12시' , '13시' , '14시' , '15시' , '16시' , '17시' , '18시' , '19시' , '20시' , '21시' , '22시']
plt.barh(time_list, lib_time_cnt, color = "green", height = [0.8], alpha = 0.5)
plt.title("요일별 시간 혼잡도 - 월요일")
plt.ylabel("입구 - 출구")
plt.tight_layout
plt.show()

# %%
# 화요일에는 어떤 시간이 가장 혼잡한가 ?

# 도서관 시간 6시 ~ 23시
# lib_AtoB : A시 00분부터 A시 59분까지의 기록
lib_6to7 = []
lib_7to8 = []
lib_8to9 = []
lib_9to10 = []
lib_10to11 = []

lib_11to12 = []
lib_12to13 = []
lib_13to14 = []
lib_14to15 = []
lib_15to16 = []

lib_16to17 = []
lib_17to18 = []
lib_18to19 = []
lib_19to20 = []
lib_20to21 = []

lib_21to22 = []
lib_22to23 = []

lib_AtoB = [
    lib_6to7,
    lib_7to8,
    lib_8to9,
    lib_9to10,
    lib_10to11,
    lib_11to12,
    lib_12to13,
    lib_13to14,
    lib_14to15,
    lib_15to16,
    lib_16to17,
    lib_17to18,
    lib_18to19,
    lib_19to20,
    lib_20to21,
    lib_21to22,
    lib_22to23
]

# 시간별로 도서관 출입 (입구 - 출구)을 저장할 리스트
lib_time_cnt = []

for i in lib_tue:
    datetime_d = datetime.strptime(i[0], '%Y/%m/%d %H:%M:%S')
    if datetime_d.hour == 6:
        lib_6to7.append([i[0],i[1]])
    elif datetime_d.hour == 7:
        lib_7to8.append([i[0],i[1]])
    elif datetime_d.hour == 8:
        lib_8to9.append([i[0],i[1]])
    elif datetime_d.hour == 9:
        lib_9to10.append([i[0],i[1]])
    elif datetime_d.hour == 10:
        lib_10to11.append([i[0],i[1]])
    elif datetime_d.hour == 11:
        lib_11to12.append([i[0],i[1]])
    elif datetime_d.hour == 12:
        lib_12to13.append([i[0],i[1]])
    elif datetime_d.hour == 13:
        lib_13to14.append([i[0],i[1]])
    elif datetime_d.hour == 14:
        lib_14to15.append([i[0],i[1]])
    elif datetime_d.hour == 15:
        lib_15to16.append([i[0],i[1]])
    elif datetime_d.hour == 16:
        lib_16to17.append([i[0],i[1]])
    elif datetime_d.hour == 17:
        lib_17to18.append([i[0],i[1]])
    elif datetime_d.hour == 18:
        lib_18to19.append([i[0],i[1]])
    elif datetime_d.hour == 19:
        lib_19to20.append([i[0],i[1]])
    elif datetime_d.hour == 20:
        lib_20to21.append([i[0],i[1]])
    elif datetime_d.hour == 21:
        lib_21to22.append([i[0],i[1]])
    elif datetime_d.hour == 22:
        lib_22to23.append([i[0],i[1]])
        

for i in lib_AtoB:
    lib_cnt = 0
    for j in i:
        if (j[1] == '입구'):
            lib_cnt += 1
        elif (j[1] == '출구'):
            lib_cnt -= 1
    lib_time_cnt.append(lib_cnt)


# print(lib_time_cnt)

# 그래프 시각화    
time_list = ['6시', '7시', '8시' , '9시' , '10시' , '11시' , '12시' , '13시' , '14시' , '15시' , '16시' , '17시' , '18시' , '19시' , '20시' , '21시' , '22시']
plt.barh(time_list, lib_time_cnt, color = "green", height = [0.8], alpha = 0.5)
plt.title("요일별 시간 혼잡도 - 화요일")
plt.ylabel("입구 - 출구")
plt.tight_layout
plt.show()

# %%
# 수요일에는 어떤 시간이 가장 혼잡한가 ?

# 도서관 시간 6시 ~ 23시
# lib_AtoB : A시 00분부터 A시 59분까지의 기록
lib_6to7 = []
lib_7to8 = []
lib_8to9 = []
lib_9to10 = []
lib_10to11 = []

lib_11to12 = []
lib_12to13 = []
lib_13to14 = []
lib_14to15 = []
lib_15to16 = []

lib_16to17 = []
lib_17to18 = []
lib_18to19 = []
lib_19to20 = []
lib_20to21 = []

lib_21to22 = []
lib_22to23 = []

lib_AtoB = [
    lib_6to7,
    lib_7to8,
    lib_8to9,
    lib_9to10,
    lib_10to11,
    lib_11to12,
    lib_12to13,
    lib_13to14,
    lib_14to15,
    lib_15to16,
    lib_16to17,
    lib_17to18,
    lib_18to19,
    lib_19to20,
    lib_20to21,
    lib_21to22,
    lib_22to23
]

# 시간별로 도서관 출입 (입구 - 출구)을 저장할 리스트
lib_time_cnt = []

for i in lib_wed:
    datetime_d = datetime.strptime(i[0], '%Y/%m/%d %H:%M:%S')
    if datetime_d.hour == 6:
        lib_6to7.append([i[0],i[1]])
    elif datetime_d.hour == 7:
        lib_7to8.append([i[0],i[1]])
    elif datetime_d.hour == 8:
        lib_8to9.append([i[0],i[1]])
    elif datetime_d.hour == 9:
        lib_9to10.append([i[0],i[1]])
    elif datetime_d.hour == 10:
        lib_10to11.append([i[0],i[1]])
    elif datetime_d.hour == 11:
        lib_11to12.append([i[0],i[1]])
    elif datetime_d.hour == 12:
        lib_12to13.append([i[0],i[1]])
    elif datetime_d.hour == 13:
        lib_13to14.append([i[0],i[1]])
    elif datetime_d.hour == 14:
        lib_14to15.append([i[0],i[1]])
    elif datetime_d.hour == 15:
        lib_15to16.append([i[0],i[1]])
    elif datetime_d.hour == 16:
        lib_16to17.append([i[0],i[1]])
    elif datetime_d.hour == 17:
        lib_17to18.append([i[0],i[1]])
    elif datetime_d.hour == 18:
        lib_18to19.append([i[0],i[1]])
    elif datetime_d.hour == 19:
        lib_19to20.append([i[0],i[1]])
    elif datetime_d.hour == 20:
        lib_20to21.append([i[0],i[1]])
    elif datetime_d.hour == 21:
        lib_21to22.append([i[0],i[1]])
    elif datetime_d.hour == 22:
        lib_22to23.append([i[0],i[1]])
        

for i in lib_AtoB:
    lib_cnt = 0
    for j in i:
        if (j[1] == '입구'):
            lib_cnt += 1
        elif (j[1] == '출구'):
            lib_cnt -= 1
    lib_time_cnt.append(lib_cnt)


# print(lib_time_cnt)

# 그래프 시각화    
time_list = ['6시', '7시', '8시' , '9시' , '10시' , '11시' , '12시' , '13시' , '14시' , '15시' , '16시' , '17시' , '18시' , '19시' , '20시' , '21시' , '22시']
plt.barh(time_list, lib_time_cnt, color = "green", height = [0.8], alpha = 0.5)
plt.title("요일별 시간 혼잡도 - 수요일")
plt.ylabel("입구 - 출구")
plt.tight_layout
plt.show()

# %%
# 목요일에는 어떤 시간이 가장 혼잡한가 ?

# 도서관 시간 6시 ~ 23시
# lib_AtoB : A시 00분부터 A시 59분까지의 기록
lib_6to7 = []
lib_7to8 = []
lib_8to9 = []
lib_9to10 = []
lib_10to11 = []

lib_11to12 = []
lib_12to13 = []
lib_13to14 = []
lib_14to15 = []
lib_15to16 = []

lib_16to17 = []
lib_17to18 = []
lib_18to19 = []
lib_19to20 = []
lib_20to21 = []

lib_21to22 = []
lib_22to23 = []

lib_AtoB = [
    lib_6to7,
    lib_7to8,
    lib_8to9,
    lib_9to10,
    lib_10to11,
    lib_11to12,
    lib_12to13,
    lib_13to14,
    lib_14to15,
    lib_15to16,
    lib_16to17,
    lib_17to18,
    lib_18to19,
    lib_19to20,
    lib_20to21,
    lib_21to22,
    lib_22to23
]

# 시간별로 도서관 출입 (입구 - 출구)을 저장할 리스트
lib_time_cnt = []

for i in lib_thu:
    datetime_d = datetime.strptime(i[0], '%Y/%m/%d %H:%M:%S')
    if datetime_d.hour == 6:
        lib_6to7.append([i[0],i[1]])
    elif datetime_d.hour == 7:
        lib_7to8.append([i[0],i[1]])
    elif datetime_d.hour == 8:
        lib_8to9.append([i[0],i[1]])
    elif datetime_d.hour == 9:
        lib_9to10.append([i[0],i[1]])
    elif datetime_d.hour == 10:
        lib_10to11.append([i[0],i[1]])
    elif datetime_d.hour == 11:
        lib_11to12.append([i[0],i[1]])
    elif datetime_d.hour == 12:
        lib_12to13.append([i[0],i[1]])
    elif datetime_d.hour == 13:
        lib_13to14.append([i[0],i[1]])
    elif datetime_d.hour == 14:
        lib_14to15.append([i[0],i[1]])
    elif datetime_d.hour == 15:
        lib_15to16.append([i[0],i[1]])
    elif datetime_d.hour == 16:
        lib_16to17.append([i[0],i[1]])
    elif datetime_d.hour == 17:
        lib_17to18.append([i[0],i[1]])
    elif datetime_d.hour == 18:
        lib_18to19.append([i[0],i[1]])
    elif datetime_d.hour == 19:
        lib_19to20.append([i[0],i[1]])
    elif datetime_d.hour == 20:
        lib_20to21.append([i[0],i[1]])
    elif datetime_d.hour == 21:
        lib_21to22.append([i[0],i[1]])
    elif datetime_d.hour == 22:
        lib_22to23.append([i[0],i[1]])
        

for i in lib_AtoB:
    lib_cnt = 0
    for j in i:
        if (j[1] == '입구'):
            lib_cnt += 1
        elif (j[1] == '출구'):
            lib_cnt -= 1
    lib_time_cnt.append(lib_cnt)


# print(lib_time_cnt)

# 그래프 시각화    
time_list = ['6시', '7시', '8시' , '9시' , '10시' , '11시' , '12시' , '13시' , '14시' , '15시' , '16시' , '17시' , '18시' , '19시' , '20시' , '21시' , '22시']
plt.barh(time_list, lib_time_cnt, color = "green", height = [0.8], alpha = 0.5)
plt.title("요일별 시간 혼잡도 - 목요일")
plt.ylabel("입구 - 출구")
plt.tight_layout
plt.show()

# %%
# 금요일에는 어떤 시간이 가장 혼잡한가 ?

# 도서관 시간 6시 ~ 23시
# lib_AtoB : A시 00분부터 A시 59분까지의 기록
lib_6to7 = []
lib_7to8 = []
lib_8to9 = []
lib_9to10 = []
lib_10to11 = []

lib_11to12 = []
lib_12to13 = []
lib_13to14 = []
lib_14to15 = []
lib_15to16 = []

lib_16to17 = []
lib_17to18 = []
lib_18to19 = []
lib_19to20 = []
lib_20to21 = []

lib_21to22 = []
lib_22to23 = []

lib_AtoB = [
    lib_6to7,
    lib_7to8,
    lib_8to9,
    lib_9to10,
    lib_10to11,
    lib_11to12,
    lib_12to13,
    lib_13to14,
    lib_14to15,
    lib_15to16,
    lib_16to17,
    lib_17to18,
    lib_18to19,
    lib_19to20,
    lib_20to21,
    lib_21to22,
    lib_22to23
]

# 시간별로 도서관 출입 (입구 - 출구)을 저장할 리스트
lib_time_cnt = []

for i in lib_fri:
    datetime_d = datetime.strptime(i[0], '%Y/%m/%d %H:%M:%S')
    if datetime_d.hour == 6:
        lib_6to7.append([i[0],i[1]])
    elif datetime_d.hour == 7:
        lib_7to8.append([i[0],i[1]])
    elif datetime_d.hour == 8:
        lib_8to9.append([i[0],i[1]])
    elif datetime_d.hour == 9:
        lib_9to10.append([i[0],i[1]])
    elif datetime_d.hour == 10:
        lib_10to11.append([i[0],i[1]])
    elif datetime_d.hour == 11:
        lib_11to12.append([i[0],i[1]])
    elif datetime_d.hour == 12:
        lib_12to13.append([i[0],i[1]])
    elif datetime_d.hour == 13:
        lib_13to14.append([i[0],i[1]])
    elif datetime_d.hour == 14:
        lib_14to15.append([i[0],i[1]])
    elif datetime_d.hour == 15:
        lib_15to16.append([i[0],i[1]])
    elif datetime_d.hour == 16:
        lib_16to17.append([i[0],i[1]])
    elif datetime_d.hour == 17:
        lib_17to18.append([i[0],i[1]])
    elif datetime_d.hour == 18:
        lib_18to19.append([i[0],i[1]])
    elif datetime_d.hour == 19:
        lib_19to20.append([i[0],i[1]])
    elif datetime_d.hour == 20:
        lib_20to21.append([i[0],i[1]])
    elif datetime_d.hour == 21:
        lib_21to22.append([i[0],i[1]])
    elif datetime_d.hour == 22:
        lib_22to23.append([i[0],i[1]])
        

for i in lib_AtoB:
    lib_cnt = 0
    for j in i:
        if (j[1] == '입구'):
            lib_cnt += 1
        elif (j[1] == '출구'):
            lib_cnt -= 1
    lib_time_cnt.append(lib_cnt)


# print(lib_time_cnt)

# 그래프 시각화    
time_list = ['6시', '7시', '8시' , '9시' , '10시' , '11시' , '12시' , '13시' , '14시' , '15시' , '16시' , '17시' , '18시' , '19시' , '20시' , '21시' , '22시']
plt.barh(time_list, lib_time_cnt, color = "green", height = [0.8], alpha = 0.5)
plt.title("요일별 시간 혼잡도 - 금요일")
plt.ylabel("입구 - 출구")
plt.tight_layout
plt.show()

# %%
# 토요일에는 어떤 시간이 가장 혼잡한가 ?

# 도서관 시간 6시 ~ 23시
# lib_AtoB : A시 00분부터 A시 59분까지의 기록
lib_6to7 = []
lib_7to8 = []
lib_8to9 = []
lib_9to10 = []
lib_10to11 = []

lib_11to12 = []
lib_12to13 = []
lib_13to14 = []
lib_14to15 = []
lib_15to16 = []

lib_16to17 = []
lib_17to18 = []
lib_18to19 = []
lib_19to20 = []
lib_20to21 = []

lib_21to22 = []
lib_22to23 = []

lib_AtoB = [
    lib_6to7,
    lib_7to8,
    lib_8to9,
    lib_9to10,
    lib_10to11,
    lib_11to12,
    lib_12to13,
    lib_13to14,
    lib_14to15,
    lib_15to16,
    lib_16to17,
    lib_17to18,
    lib_18to19,
    lib_19to20,
    lib_20to21,
    lib_21to22,
    lib_22to23
]

# 시간별로 도서관 출입 (입구 - 출구)을 저장할 리스트
lib_time_cnt = []

for i in lib_sat:
    datetime_d = datetime.strptime(i[0], '%Y/%m/%d %H:%M:%S')
    if datetime_d.hour == 6:
        lib_6to7.append([i[0],i[1]])
    elif datetime_d.hour == 7:
        lib_7to8.append([i[0],i[1]])
    elif datetime_d.hour == 8:
        lib_8to9.append([i[0],i[1]])
    elif datetime_d.hour == 9:
        lib_9to10.append([i[0],i[1]])
    elif datetime_d.hour == 10:
        lib_10to11.append([i[0],i[1]])
    elif datetime_d.hour == 11:
        lib_11to12.append([i[0],i[1]])
    elif datetime_d.hour == 12:
        lib_12to13.append([i[0],i[1]])
    elif datetime_d.hour == 13:
        lib_13to14.append([i[0],i[1]])
    elif datetime_d.hour == 14:
        lib_14to15.append([i[0],i[1]])
    elif datetime_d.hour == 15:
        lib_15to16.append([i[0],i[1]])
    elif datetime_d.hour == 16:
        lib_16to17.append([i[0],i[1]])
    elif datetime_d.hour == 17:
        lib_17to18.append([i[0],i[1]])
    elif datetime_d.hour == 18:
        lib_18to19.append([i[0],i[1]])
    elif datetime_d.hour == 19:
        lib_19to20.append([i[0],i[1]])
    elif datetime_d.hour == 20:
        lib_20to21.append([i[0],i[1]])
    elif datetime_d.hour == 21:
        lib_21to22.append([i[0],i[1]])
    elif datetime_d.hour == 22:
        lib_22to23.append([i[0],i[1]])
        

for i in lib_AtoB:
    lib_cnt = 0
    for j in i:
        if (j[1] == '입구'):
            lib_cnt += 1
        elif (j[1] == '출구'):
            lib_cnt -= 1
    lib_time_cnt.append(lib_cnt)


# print(lib_time_cnt)

# 그래프 시각화    
time_list = ['6시', '7시', '8시' , '9시' , '10시' , '11시' , '12시' , '13시' , '14시' , '15시' , '16시' , '17시' , '18시' , '19시' , '20시' , '21시' , '22시']
plt.barh(time_list, lib_time_cnt, color = "green", height = [0.8], alpha = 0.5)
plt.title("요일별 시간 혼잡도 - 토요일")
plt.ylabel("입구 - 출구")
plt.tight_layout
plt.show()

# %%
# 일요일에는 어떤 시간이 가장 혼잡한가 ?

# 도서관 시간 6시 ~ 23시
# lib_AtoB : A시 00분부터 A시 59분까지의 기록
lib_6to7 = []
lib_7to8 = []
lib_8to9 = []
lib_9to10 = []
lib_10to11 = []

lib_11to12 = []
lib_12to13 = []
lib_13to14 = []
lib_14to15 = []
lib_15to16 = []

lib_16to17 = []
lib_17to18 = []
lib_18to19 = []
lib_19to20 = []
lib_20to21 = []

lib_21to22 = []
lib_22to23 = []

lib_AtoB = [
    lib_6to7,
    lib_7to8,
    lib_8to9,
    lib_9to10,
    lib_10to11,
    lib_11to12,
    lib_12to13,
    lib_13to14,
    lib_14to15,
    lib_15to16,
    lib_16to17,
    lib_17to18,
    lib_18to19,
    lib_19to20,
    lib_20to21,
    lib_21to22,
    lib_22to23
]

# 시간별로 도서관 출입 (입구 - 출구)을 저장할 리스트
lib_time_cnt = []

for i in lib_sun:
    datetime_d = datetime.strptime(i[0], '%Y/%m/%d %H:%M:%S')
    if datetime_d.hour == 6:
        lib_6to7.append([i[0],i[1]])
    elif datetime_d.hour == 7:
        lib_7to8.append([i[0],i[1]])
    elif datetime_d.hour == 8:
        lib_8to9.append([i[0],i[1]])
    elif datetime_d.hour == 9:
        lib_9to10.append([i[0],i[1]])
    elif datetime_d.hour == 10:
        lib_10to11.append([i[0],i[1]])
    elif datetime_d.hour == 11:
        lib_11to12.append([i[0],i[1]])
    elif datetime_d.hour == 12:
        lib_12to13.append([i[0],i[1]])
    elif datetime_d.hour == 13:
        lib_13to14.append([i[0],i[1]])
    elif datetime_d.hour == 14:
        lib_14to15.append([i[0],i[1]])
    elif datetime_d.hour == 15:
        lib_15to16.append([i[0],i[1]])
    elif datetime_d.hour == 16:
        lib_16to17.append([i[0],i[1]])
    elif datetime_d.hour == 17:
        lib_17to18.append([i[0],i[1]])
    elif datetime_d.hour == 18:
        lib_18to19.append([i[0],i[1]])
    elif datetime_d.hour == 19:
        lib_19to20.append([i[0],i[1]])
    elif datetime_d.hour == 20:
        lib_20to21.append([i[0],i[1]])
    elif datetime_d.hour == 21:
        lib_21to22.append([i[0],i[1]])
    elif datetime_d.hour == 22:
        lib_22to23.append([i[0],i[1]])
        

for i in lib_AtoB:
    lib_cnt = 0
    for j in i:
        if (j[1] == '입구'):
            lib_cnt += 1
        elif (j[1] == '출구'):
            lib_cnt -= 1
    lib_time_cnt.append(lib_cnt)


# print(lib_time_cnt)

# 그래프 시각화    
time_list = ['6시', '7시', '8시' , '9시' , '10시' , '11시' , '12시' , '13시' , '14시' , '15시' , '16시' , '17시' , '18시' , '19시' , '20시' , '21시' , '22시']
plt.barh(time_list, lib_time_cnt, color = "green", height = [0.8], alpha = 0.5)
plt.title("요일별 시간 혼잡도 - 일요일")
plt.ylabel("입구 - 출구")
plt.tight_layout
plt.show()
